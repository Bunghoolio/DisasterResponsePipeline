# %% [markdown]
# # ML Pipeline Preparation
# Follow the instructions below to help you create your ML pipeline.
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
# import libraries
import pandas as pd
import re
import numpy as np
from sqlalchemy import create_engine
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.metrics import classification_report, multilabel_confusion_matrix
from sklearn.naive_bayes import MultinomialNB
from joblib import dump

# %%
# load data from database
engine = create_engine('sqlite:///DisasterResponse.db')
df = pd.read_sql_table('categorized_messages', engine)

# %%
df.nunique()[df.nunique()==1]
# Out:
# child_alone    1
# dtype: int64

# %%
X = df['message']
y = df.drop(columns=['id','message','original','genre', 'child_alone'])
category_names = y.columns.tolist()

# %% [markdown]
# ### 2. Write a tokenization function to process your text data

# %%
def tokenize(text):
    
    # get list of all urls using regex
    url_regex = 'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'
    detected_urls = re.findall(url_regex, text)
    
    # replace each url in text string with placeholder
    for url in detected_urls:
        text = text.replace(url, 'urlplaceholder')

    # Remove punctuation characters
    text = re.sub(r'[^a-zA-Z0-9äöüÄÖÜß ]', '', text.lower())
    
    # tokenize
    tokens = word_tokenize(text)
    
    # Remove stop words
    tokens = [tok for tok in tokens if tok not in stopwords.words("english")]

    # instantiate lemmatizer and stemmer
    lemmatizer = WordNetLemmatizer()
    stemmer = PorterStemmer()

    # lemmatize and stemm
    clean_tokens = []
    for tok in tokens:
        lemm_tok = lemmatizer.lemmatize(tok).lower().strip()
        clean_tok = stemmer.stem(tok)
        clean_tokens.append(clean_tok)

    return clean_tokens

# %% [markdown]
# ### 3. Build a machine learning pipeline
# This machine pipeline should take in the `message` column as input and output classification results on the other 36 categories in the dataset. You may find the [MultiOutputClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html) helpful for predicting multiple target variables.

# %%
def init_pipelines():

    #Random Forest Classifier Pipeline
    pipe_rfc = Pipeline([
        ('vect', CountVectorizer(tokenizer = tokenize)),
        ('tfidf', TfidfTransformer()),
        ('clf', MultiOutputClassifier(RandomForestClassifier()))
    ])

    #Gradient Boost Classifier Pipeline
    pipe_gbc = Pipeline([
        ('vect', CountVectorizer(tokenizer = tokenize)),
        ('tfidf', TfidfTransformer()),
        ('clf', MultiOutputClassifier(GradientBoostingClassifier()))
    ])

    #ADA Boost Classifier Pipeline 
    pipe_abc = Pipeline([
        ('vect', CountVectorizer(tokenizer = tokenize)),
        ('tfidf', TfidfTransformer()),
        ('clf', MultiOutputClassifier(AdaBoostClassifier()))
    ])

    pipelines = [pipe_rfc, pipe_gbc, pipe_abc]
    
    return pipelines

# %% [markdown]
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %%
def train_pipeline(pipeline, X_train_array, y_train_array, n_jobs=-1):

    #setting pipeline parameters
    if 'clf__estimator__n_jobs' in pipeline.get_params():
        pipeline.set_params(clf__estimator__n_jobs=n_jobs)
    
    #fitting pipeline
    pipeline.fit(X_train_array, y_train_array)
    
    return pipeline

# %% [markdown]
# ### 5. Test your model
# Report the f1 score, precision and recall for each output category of the dataset. You can do this by iterating through the columns and calling sklearn's `classification_report` on each.

# %%
def eval_pipeline(pipeline, X_test_array, y_test, column_names):
    
    #predicting y_test
    y_pred = pd.DataFrame(pipeline.predict(X_test_array), columns=y_train.columns.tolist())
        
    #classifier used:
    classifier_name = str(pipeline.get_params()['steps'][2][1]).replace('(','').replace(')','').replace('n_jobs','').split('=')[1]
    
    #printing classification report
    print('_________________________________ {} ___________________________________________________\n'.format(classifier_name))
    for i, col in enumerate(y_test):
        print('{}\n{}'.format(col, classification_report(y_test[col], y_pred[col], zero_division=0)))
        
    print('____________________________________________________________________________________\n')

# %%
pipelines = init_pipelines()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=42)
X_train_array, y_train_array, X_test_array = np.array(X_train), np.array(y_train), np.array(X_test)
    
column_names = y_train.columns.tolist()

for pipe in pipelines:
    pipe = train_pipeline(pipe, X_train_array, y_train_array)
    eval_pipeline(pipe, X_test_array, y_test, column_names)
# Out:
# _________________________________ RandomForestClassifier ___________________________________________________
#
# related
#               precision    recall  f1-score   support
#
#            0       0.71      0.41      0.53      1873
#            1       0.83      0.95      0.89      5934
#            2       0.50      0.50      0.50        58
#
#     accuracy                           0.82      7865
#    macro avg       0.68      0.62      0.64      7865
# weighted avg       0.80      0.82      0.80      7865
#
# request
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94      6533
#            1       0.84      0.47      0.61      1332
#
#     accuracy                           0.90      7865
#    macro avg       0.87      0.73      0.77      7865
# weighted avg       0.89      0.90      0.88      7865
#
# offer
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7829
#            1       0.00      0.00      0.00        36
#
#     accuracy                           1.00      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      1.00      0.99      7865
#
# aid_related
#               precision    recall  f1-score   support
#
#            0       0.79      0.83      0.81      4646
#            1       0.74      0.69      0.71      3219
#
#     accuracy                           0.77      7865
#    macro avg       0.77      0.76      0.76      7865
# weighted avg       0.77      0.77      0.77      7865
#
# medical_help
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      7227
#            1       0.67      0.08      0.14       638
#
#     accuracy                           0.92      7865
#    macro avg       0.80      0.54      0.55      7865
# weighted avg       0.90      0.92      0.89      7865
#
# medical_products
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      7447
#            1       0.79      0.07      0.14       418
#
#     accuracy                           0.95      7865
#    macro avg       0.87      0.54      0.55      7865
# weighted avg       0.94      0.95      0.93      7865
#
# search_and_rescue
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7673
#            1       0
7865
#
# electricity
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7697
#            1       0.59      0.20      0.30       168
#
#     accuracy                           0.98      7865
#    macro avg       0.78      0.60      0.65      7865
# weighted avg       0.97      0.98      0.98      7865
#
# tools
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      7817
#            1       0.11      0.02      0.04        48
#
#     accuracy                           0.99      7865
#    macro avg       0.55      0.51      0.52      7865
# weighted avg       0.99      0.99      0.99      7865
#
# hospitals
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7787
#            1       0.26      0.10      0.15        78
#
#     accuracy                           0.99      7865
#    macro avg       0.62      0.55      0.57      7865
# weighted avg       0.98      0.99      0.99      7865
#
# shops
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7837
#            1       0.00      0.00      0.00        28
#
#     accuracy                           1.00      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      1.00      0.99      7865
#
# aid_centers
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7762
#            1       0.22      0.07      0.10       103
#
#     accuracy                           0.98      7865
#    macro avg       0.60      0.53      0.55      7865
# weighted avg       0.98      0.98      0.98      7865
#
# other_infrastructure
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      7524
#            1       0.40      0.10      0.16       341
#
#     accuracy                           0.95      7865
#    macro avg       0.68      0.55      0.57      7865
# weighted avg       0.94      0.95      0.94      7865
#
# weather_related
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91      5702
#            1       0.84      0.65      0.73      2163
#
#     accuracy                           0.87      7865
#    macro avg       0.86      0.80      0.82      7865
# weighted avg       0.87      0.87      0.86      7865
#
# floods
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      7242
#            1       0.85      0.59      0.70       623
#
#     accuracy                           0.96      7865
#    macro avg       0.91      0.79      0.84      7865
# weighted avg       0.96      0.96      0.96      7865
#
# storm
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96      7127
#            1       0.75      0.44      0.55       738
#
#     accuracy                           0.93      7865
#    macro avg       0.85      0.71      0.76      7865
# weighted avg       0.93      0.93      0.93      7865
#
# fire
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7782
#            1       0.46      0.16      0.23        83
#
#     accuracy                           0.99      7865
#    macro avg       0.73      0.58      0.61      7865
# weighted avg       0.99      0.99      0.99      7865
#
# earthquake
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      7163
#            1       0.88      0.76      0.82       702
#
#     accuracy                           0.97      7865
#    macro avg       0.93      0.88      0.90      7865
# weighted avg       0.97      0.97      0.97      7865
#
# cold
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7694
#            1       0.69      0.33      0.44       171
#
#     accuracy                           0.98      7865
#    macro avg       0.84      0.66      0.72      7865
# weighted avg       0.98      0.98      0.98      7865
#
# other_weather
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97      7450
#            1       0.49      0.17      0.25       415
#
#     accuracy                           0.95      7865
#    macro avg       0.72      0.58      0.61      7865
# weighted avg       0.93      0.95      0.93      7865
#
# direct_report
#               precision    recall  f1-score   support
#
#            0       0.86      0.96      0.91      6321
#            1       0.69      0.38      0.50      1544
#
#     accuracy                           0.85      7865
#    macro avg       0.78      0.67      0.70      7865
# weighted avg       0.83      0.85      0.83      7865
#
# ____________________________________________________________________________________

# %% [markdown]
# ### 6. Improve your model
# Use grid search to find better parameters.

# %%
params_rfc = {'tfidf__use_idf': [True],
              'clf__estimator__n_estimators':[100,200],
              'clf__estimator__min_samples_split':[2,5],
              'clf__estimator__n_jobs':[-1]
}

params_gbc = {'tfidf__use_idf': [True,False],
              'clf__estimator__n_estimators': [100, 200],
              'clf__estimator__learning_rate': [.05, .1]
}

params_abc = {'tfidf__use_idf': [True,False],
              'clf__estimator__n_estimators': [200, 300],
              'clf__estimator__learning_rate': [.15, .2]
}

params_gs = [params_rfc, params_gbc, params_abc]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=42)
X_train_array, y_train_array, X_test_array = np.array(X_train), np.array(y_train), np.array(X_test)
    
column_names = y_train.columns.tolist()

pipelines = init_pipelines()
cv_list = []
results = []

for i, pipe in enumerate(pipelines):
    print(pipe)
    cv = GridSearchCV(pipe, param_grid=params_gs[i], verbose=3, return_train_score=True)
    cv.fit(X_train_array, y_train_array)
    cv_list.append(cv)
    results.append(cv.cv_results_)
    eval_pipeline(cv.best_estimator_, X_test_array, y_test, column_names)
# Out:
# Pipeline(steps=[('vect',
#                  CountVectorizer(tokenizer=<function tokenize at 0x000002592B0C2040>)),
#                 ('tfidf', TfidfTransformer()),
#                 ('clf',
#                  MultiOutputClassifier(estimator=RandomForestClassifier()))])
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.995, test=0.267), total= 3.6min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  5.4min remaining:    0.0s
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.995, test=0.263), total= 3.6min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed: 10.7min remaining:    0.0s
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.995, test=0.262), total= 3.7min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.994, test=0.263), total= 3.6min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.995, test=0.268), total= 3.6min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.996, test=0.270), total= 5.0min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.996, test=0.257), total= 6.5min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.996, test=0.266), total= 6.3min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.995, test=0.261), total= 6.5min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.996, test=0.273), total= 6.6min
# [CV] clf__estimator__min_samples_split=5, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [CV]  clf__estimator__min_samples_split=5, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.909, test=0.269), total= 4.2min
# [CV] clf__estimator__min_samples_split=5, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [CV]  clf__estimator__min_samples_split=5, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.906, test=0.254), total= 4.0min
# [CV] clf__estimator__min_samples_split=5, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [CV]  clf__estimator__min_samples_split=5, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.906, test=0.259), total= 4.1min
# [CV] clf__estimator__min_samples_split=5, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [CV]  clf__estimator__min_samples_split=5, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.907, test=0.255), total= 4.2min
# [CV] clf__estimator__min_samples_split=5, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [CV]  clf__estimator__min_samples_split=5, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.910, test=0.267), total= 4.1min
# [CV] clf__estimator__min_samples_split=5, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [CV]  clf__estimator__min_samples_split=5, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.923, test=0.269), total= 5.7min
# [CV] clf__estimator__min_samples_split=5, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [CV]  clf__estimator__min_samples_split=5, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.922, test=0.260), total= 5.9min
# [CV] clf__estimator__min_samples_split=5, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [CV]  clf__estimator__min_samples_split=5, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.922, test=0.265), total= 5.7min
# [CV] clf__estimator__min_samples_split=5, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [CV]  clf__estimator__min_samples_split=5, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0
________________________________________________________________________
#
# Pipeline(steps=[('vect',
#                  CountVectorizer(tokenizer=<function tokenize at 0x000002592B0C2040>)),
#                 ('tfidf', TfidfTransformer()),
#                 ('clf',
#                  MultiOutputClassifier(estimator=GradientBoostingClassifier()))])
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=True
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=True, score=(train=0.281, test=0.232), total= 6.4min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=True
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  8.1min remaining:    0.0s
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=True, score=(train=0.280, test=0.220), total= 6.3min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=True
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed: 16.2min remaining:    0.0s
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=True, score=(train=0.277, test=0.237), total= 6.3min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=True, score=(train=0.278, test=0.234), total= 6.5min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=True, score=(train=0.272, test=0.244), total= 6.4min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=False, score=(train=0.281, test=0.236), total= 6.0min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=False, score=(train=0.281, test=0.225), total= 5.7min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=False, score=(train=0.277, test=0.238), total= 5.8min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=False, score=(train=0.279, test=0.239), total= 5.5min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=False, score=(train=0.271, test=0.245), total= 4.8min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.315, test=0.251), total= 9.0min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.316, test=0.243), total=10.3min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.314, test=0.250), total=10.3min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.316, test=0.246), total=10.5min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.312, test=0.259), total=10.4min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.315, test=0.253), total= 9.2min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.319, test=0.245), total= 9.7min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.314, test=0.256), total= 9.0min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.314, test=0.256), total= 9.0min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.312, test=0.265), total= 9.0min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=True, score=(train=0.323, test=0.236), total= 6.4min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=True, score=(train=0.326, test=0.231), total= 6.3min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=True, score=(train=0.322, test=0.238), total= 5.6min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=True, score=(train=0.322, test=0.237), total= 5.7min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=True, score=(train=0.322, test=0.250), total= 6.6min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=False, score=(train=0.322, test=0.239), total= 6.0min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=False, score=(train=0.323, test=0.233), total= 6.0min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=False, score=(train=0.322, test=0.241), total= 6.1min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=False, score=(train=0.322, test=0.241), total= 6.1min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=False, score=(train=0.321, test=0.252), total= 6.1min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.371, test=0.245), total=10.2min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.372, test=0.241), total=10.7min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.378, test=0.243), total=10.2min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.375, test=0.249), total=10.2min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.371, test=0.258), total=10.3min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.373, test=0.253), total= 9.0min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.374, test=0.244), total= 9.1min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.372, test=0.249), total= 9.1min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.372, test=0.250), total= 9.1min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.368, test=0.265), total= 9.2min
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed: 389.7min finished
# _________________________________ GradientBoostingClassifierlearning_rate ___________________________________________________
#
# related
#               precision    recall  f1-score   support
#
#            0       0.75      0.21      0.32      1873
#            1       0.79      0.98      0.87      5934
#            2       0.74      0.24      0.36        58
#
#     accuracy                           0.79      7865
#    macro avg       0.76      0.48      0.52      7865
# weighted avg       0.78      0.79      0.74      7865
#
# request
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94      6533
#            1       0.84      0.46      0.60      1332
#
#     accuracy                           0.89      7865
#    macro avg       0.87      0.72      0.77      7865
# weighted avg       0.89      0.89      0.88      7865
#
# offer
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7829
#            1       0.00      0.00      0.00        36
#
#     accuracy                           0.99      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      0.99      0.99      7865
#
# aid_related
#               precision    recall  f1-score   support
#
#            0       0.74      0.89      0.81      4646
#            1       0.78      0.56      0.65      3219
#
#     accuracy                           0.76      7865
#    macro avg       0.76      0.73      0.73      7865
# weighted avg       0.76      0.76      0.75      7865
#
# medical_help
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96      7227
#            1       0.63      0.23      0.34       638
#
#     accuracy                           0.93      7865
#    macro avg       0.78      0.61      0.65      7865
# weighted avg       0.91      0.93      0.91      7865
#
# medical_products
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      7447
#            1       0.71      0.27      0.39       418
#
#     accuracy                           0.96      7865
#    macro avg       0.84      0.63      0.68      7865
# weighted avg       0.95      0.96      0.95      7865
#
# search_and_rescue
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7673
#            1       0.66      0.21      0.32       192
#
#     accuracy                           0.98      7865
#    macro avg       0.82      0.61      0.66      7865
# weighted avg       0.97      0.98      0.97      7865
#
# security
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7721
#            1       0.33      0.01      0.01       144
#
#     accuracy                           0.98      7865
#    macro avg       0.66      0.50      0.50      7865
# weighted avg       0.97      0.98      0.97      7865
#
# military
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      7620
#            1       0.56      0.22      0.32       245
#
#     accuracy                           0.97      7865
#    macro avg       0.77      0.61      0.65      7865
# weighted avg       0.96      0.97      0.96      7865
#
# water
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      7365
#            1       0.76      0.62      0.68       500
#
#     accuracy                           0.96      7865
#    macro avg       0.87      0.80      0.83      7865
# weighted avg       0.96      0.96      0.96      7865
#
# food
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97      6987
#            1       0.82      0.78      0.80       878
#
#     accuracy                           0.96      7865
#    macro avg       0.89      0.88      0.89      7865
# weighted avg       0.95      0.96      0.95      7865
#
# shelter
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97      7160
#            1       0.80      0.54      0.64       705
#
#     accuracy                           0.95      7865
#    macro avg       0.88      0.76      0.81      7865
# weighted avg       0.94      0.95      0.94      7865
#
# clothing
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7750
#            1       0.61      0.50      0.55       115
#
#     accuracy                           0.99      7865
#    macro avg       0.80      0.75      0.77      7865
# weighted avg       0.99      0.99      0.99      7865
#
# money
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7695
#            1       0.60      0.24      0.34       170
#
#     accuracy                           0.98      7865
#    macro avg       0.79      0.62      0.66      7865
# weighted avg       0.97      0.98      0.98      7865
#
# missing_people
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7773
#            1       0.33      0.20      0.25        92
#
#     accuracy                           0.99      7865
#    macro avg       0.66      0.60      0.62      7865
# weighted avg       0.98      0.99      0.98      7865
#
# refugees
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      7605
#            1       0.60      0.27      0.37       260
#
#     accuracy                           0.97      7865
#    macro avg       0.79      0.63      0.68      7865
# weighted avg       0.96      0.97      0.96      7865
#
# death
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      7499
#            1       0.77      0.50      0.61       366
#
#     accuracy                           0.97      7865
#    macro avg       0.87      0.75      0.80      7865
# weighted avg       0.97      0.97      0.97      7865
#
# other_aid
#               precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93      6832
#            1       0.54      0.08      0.13      1033
#
#     accuracy                           0.87      7865
#    macro avg       0.71      0.53      0.53      7865
# weighted avg       0.83      0.87      0.83      7865
#
# infrastructure_related
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      7360
#            1       0.50      0.03      0.05       505
#
#     accuracy                           0.94      7865
#    macro avg       0.72      0.51      0.51      7865
# weighted avg       0.91      0.94      0.91      7865
#
# transport
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7503
#            1       0.76      0.22      0.34       362
#
#     accuracy                           0.96      7865
#    macro avg       0.86      0.61      0.66      7865
# weighted avg       0.95      0.96      0.95      7865
#
# buildings
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7473
#            1       0.82      0.31      0.45       392
#
#     accuracy                           0.96      7865
#    macro avg       0.89      0.65      0.71      7865
# weighted avg       0.96      0.96      0.95      7865
#
# electricity
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      7697
#            1       0.41      0.19      0.26       168
#
#     accuracy                           0.98      7865
#    macro avg       0.70      0.59      0.62      7865
# weighted avg       0.97      0.98      0.97      7865
#
# tools
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      7817
#            1       0.00      0.00      0.00        48
#
#     accuracy                           0.99      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      0.99      0.99      7865
#
# hospitals
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7787
#            1       0.06      0.03      0.04        78
#
#     accuracy                           0.99      7865
#    macro avg       0.52      0.51      0.51      7865
# weighted avg       0.98      0.99      0.98      7865
#
# shops
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7837
#            1       0.00      0.00      0.00        28
#
#     accuracy                           0.99      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      0.99      0.99      7865
#
# aid_centers
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7762
#            1       0.11      0.04      0.06       103
#
#     accuracy                           0.98      7865
#    macro avg       0.55      0.52      0.52      7865
# weighted avg       0.98      0.98      0.98      7865
#
# other_infrastructure
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7524
#            1       0.50      0.03      0.05       341
#
#     accuracy                           0.96      7865
#    macro avg       0.73      0.51      0.51      7865
# weighted avg       0.94      0.96      0.94      7865
#
# weather_related
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.91      5702
#            1       0.87      0.61      0.72      2163
#
#     accuracy                           0.87      7865
#    macro avg       0.87      0.79      0.81      7865
# weighted avg       0.87      0.87      0.86      7865
#
# floods
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      7242
#            1       0.88      0.57      0.69       623
#
#     accuracy                           0.96      7865
#    macro avg       0.92      0.78      0.83      7865
# weighted avg       0.96      0.96      0.96      7865
#
# storm
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      7127
#            1       0.76      0.62      0.68       738
#
#     accuracy                           0.95      7865
#    macro avg       0.86      0.80      0.82      7865
# weighted avg       0.94      0.95      0.94      7865
#
# fire
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7782
#            1       0.36      0.28      0.31        83
#
#     accuracy                           0.99      7865
#    macro avg       0.68      0.64      0.65      7865
# weighted avg       0.99      0.99      0.99      7865
#
# earthquake
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      7163
#            1       0.88      0.79      0.83       702
#
#     accuracy                           0.97      7865
#    macro avg       0.93      0.89      0.91      7865
# weighted avg       0.97      0.97      0.97      7865
#
# cold
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7694
#            1       0.61      0.38      0.47       171
#
#     accuracy                           0.98      7865
#    macro avg       0.80      0.69      0.73      7865
# weighted avg       0.98      0.98      0.98      7865
#
# other_weather
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      7450
#            1       0.52      0.08      0.14       415
#
#     accuracy                           0.95      7865
#    macro avg       0.73      0.54      0.56      7865
# weighted avg       0.93      0.95      0.93      7865
#
# direct_report
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.91      6321
#            1       0.78      0.33      0.46      1544
#
#     accuracy                           0.85      7865
#    macro avg       0.82      0.65      0.69      7865
# weighted avg       0.84      0.85      0.82      7865
#
# ____________________________________________________________________________________
#
# Pipeline(steps=[('vect',
#                  CountVectorizer(tokenizer=<function tokenize at 0x000002592B0C2040>)),
#                 ('tfidf', TfidfTransformer()),
#                 ('clf', MultiOutputClassifier(estimator=AdaBoostClassifier()))])
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.232, test=0.223), total= 6.4min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  8.8min remaining:    0.0s
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.235, test=0.205), total= 6.4min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed: 17.7min remaining:    0.0s
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.231, test=0.226), total= 6.4min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.233, test=0.225), total= 6.5min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.231, test=0.233), total= 6.4min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.231, test=0.223), total= 6.0min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.234, test=0.208), total= 5.9min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.231, test=0.227), total= 6.0min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.240, test=0.229), total= 5.9min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.231, test=0.233), total= 6.0min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=True, score=(train=0.259, test=0.245), total= 8.2min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=True, score=(train=0.248, test=0.214), total= 8.2min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=True, score=(train=0.241, test=0.233), total= 8.2min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=True, score=(train=0.250, test=0.234), total= 8.2min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=True, score=(train=0.242, test=0.236), total= 8.2min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=False, score=(train=0.248, test=0.236), total= 6.7min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=False, score=(train=0.253, test=0.216), total= 6.3min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=False, score=(train=0.240, test=0.231), total= 7.5min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=False, score=(train=0.251, test=0.237), total= 7.5min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=False, score=(train=0.243, test=0.238), total= 7.6min
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.245, test=0.232), total= 6.5min
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.248, test=0.217), total= 6.5min
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.238, test=0.230), total= 6.5min
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.246, test=0.231), total= 6.4min
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.237, test=0.232), total= 6.0min
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.242, test=0.232), total= 5.0min
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.249, test=0.216), total= 5.5min
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.238, test=0.227), total= 6.0min
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.245, test=0.232), total= 6.0min
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.240, test=0.235), total= 6.0min
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=True, score=(train=0.281, test=0.254), total=11.0min
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=True, score=(train=0.273, test=0.231), total= 7.1min
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=True, score=(train=0.256, test=0.245), total= 8.1min
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=True, score=(train=0.271, test=0.244), total= 8.2min
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=True, score=(train=0.269, test=0.253), total= 8.2min
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=False, score=(train=0.276, test=0.259), total= 7.5min
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=False, score=(train=0.274, test=0.229), total= 7.5min
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=False, score=(train=0.256, test=0.237), total= 7.5min
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=False, score=(train=0.270, test=0.243), total= 6.3min
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=False, score=(train=0.265, test=0.249), total=10.0min
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed: 381.1min finished
# _________________________________ AdaBoostClassifierlearning_rate ___________________________________________________
#
# related
#               precision    recall  f1-score   support
#
#            0       0.71      0.05      0.09      1873
#            1       0.76      0.99      0.86      5934
#            2       0.57      0.07      0.12        58
#
#     accuracy                           0.76      7865
#    macro avg       0.68      0.37      0.36      7865
# weighted avg       0.75      0.76      0.67      7865
#
# request
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94      6533
#            1       0.83      0.47      0.60      1332
#
#     accuracy                           0.89      7865
#    macro avg       0.87      0.73      0.77      7865
# weighted avg       0.89      0.89      0.88      7865
#
# offer
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7829
#            1       0.00      0.00      0.00        36
#
#     accuracy                           1.00      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      1.00      0.99      7865
#
# aid_related
#               precision    recall  f1-score   support
#
#            0       0.76      0.88      0.82      4646
#            1       0.78      0.59      0.67      3219
#
#     accuracy                           0.76      7865
#    macro avg       0.77      0.74      0.74      7865
# weighted avg       0.77      0.76      0.76      7865
#
# medical_help
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96      7227
#            1       0.58      0.17      0.27       638
#
#     accuracy                           0.92      7865
#    macro avg       0.76      0.58      0.61      7865
# weighted avg       0.90      0.92      0.90      7865
#
# medical_products
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      7447
#            1       0.70      0.22      0.33       418
#
#     accuracy                           0.95      7865
#    macro avg       0.83      0.61      0.65      7865
# weighted avg       0.94      0.95      0.94      7865
#
# search_and_rescue
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7673
#            1       0.76      0.13      0.22       192
#
#     accuracy                           0.98      7865
#    macro avg       0.87      0.56      0.61      7865
# weighted avg       0.97      0.98      0.97      7865
#
# security
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7721
#            1       0.00      0.00      0.00       144
#
#     accuracy                           0.98      7865
#    macro avg       0.49      0.50      0.50      7865
# weighted avg       0.96      0.98      0.97      7865
#
# military
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      7620
#            1       0.55      0.20      0.29       245
#
#     accuracy                           0.97      7865
#    macro avg       0.76      0.60      0.64      7865
# weighted avg       0.96      0.97      0.96      7865
#
# water
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      7365
#            1       0.76      0.63      0.69       500
#
#     accuracy                           0.96      7865
#    macro avg       0.87      0.81      0.84      7865
# weighted avg       0.96      0.96      0.96      7865
#
# food
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      6987
#            1       0.82      0.71      0.76       878
#
#     accuracy                           0.95      7865
#    macro avg       0.89      0.85      0.87      7865
# weighted avg       0.95      0.95      0.95      7865
#
# shelter
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      7160
#            1       0.81      0.51      0.62       705
#
#     accuracy                           0.95      7865
#    macro avg       0.88      0.75      0.80      7865
# weighted avg       0.94      0.95      0.94      7865
#
# clothing
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7750
#            1       0.69      0.30      0.42       115
#
#     accuracy                           0.99      7865
#    macro avg       0.84      0.65      0.71      7865
# weighted avg       0.99      0.99      0.99      7865
#
# money
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7695
#            1       0.51      0.20      0.29       170
#
#     accuracy                           0.98      7865
#    macro avg       0.75      0.60      0.64      7865
# weighted avg       0.97      0.98      0.97      7865
#
# missing_people
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7773
#            1       0.67      0.11      0.19        92
#
#     accuracy                           0.99      7865
#    macro avg       0.83      0.55      0.59      7865
# weighted avg       0.99      0.99      0.98      7865
#
# refugees
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      7605
#            1       0.63      0.22      0.32       260
#
#     accuracy                           0.97      7865
#    macro avg       0.80      0.61      0.65      7865
# weighted avg       0.96      0.97      0.96      7865
#
# death
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      7499
#            1       0.80      0.35      0.48       366
#
#     accuracy                           0.97      7865
#    macro avg       0.88      0.67      0.73      7865
# weighted avg       0.96      0.97      0.96      7865
#
# other_aid
#               precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93      6832
#            1       0.56      0.08      0.13      1033
#
#     accuracy                           0.87      7865
#    macro avg       0.72      0.53      0.53      7865
# weighted avg       0.83      0.87      0.83      7865
#
# infrastructure_related
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      7360
#            1       0.63      0.05      0.10       505
#
#     accuracy                           0.94      7865
#    macro avg       0.79      0.52      0.53      7865
# weighted avg       0.92      0.94      0.91      7865
#
# transport
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7503
#            1       0.78      0.14      0.23       362
#
#     accuracy                           0.96      7865
#    macro avg       0.87      0.57      0.61      7865
# weighted avg       0.95      0.96      0.94      7865
#
# buildings
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7473
#            1       0.79      0.31      0.44       392
#
#     accuracy                           0.96      7865
#    macro avg       0.88      0.65      0.71      7865
# weighted avg       0.96      0.96      0.95      7865
#
# electricity
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7697
#            1       0.65      0.14      0.23       168
#
#     accuracy                           0.98      7865
#    macro avg       0.82      0.57      0.61      7865
# weighted avg       0.97      0.98      0.97      7865
#
# tools
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      7817
#            1       0.00      0.00      0.00        48
#
#     accuracy                           0.99      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      0.99      0.99      7865
#
# hospitals
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7787
#            1       0.44      0.10      0.17        78
#
#     accuracy                           0.99      7865
#    macro avg       0.72      0.55      0.58      7865
# weighted avg       0.99      0.99      0.99      7865
#
# shops
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7837
#            1       0.00      0.00      0.00        28
#
#     accuracy                           1.00      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      1.00      0.99      7865
#
# aid_centers
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7762
#            1       0.27      0.03      0.05       103
#
#     accuracy                           0.99      7865
#    macro avg       0.63      0.51      0.52      7865
# weighted avg       0.98      0.99      0.98      7865
#
# other_infrastructure
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7524
#            1       0.44      0.04      0.07       341
#
#     accuracy                           0.96      7865
#    macro avg       0.70      0.52      0.52      7865
# weighted avg       0.94      0.96      0.94      7865
#
# weather_related
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.91      5702
#            1       0.87      0.61      0.71      2163
#
#     accuracy                           0.87      7865
#    macro avg       0.87      0.79      0.81      7865
# weighted avg       0.87      0.87      0.86      7865
#
# floods
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      7242
#            1       0.87      0.54      0.67       623
#
#     accuracy                           0.96      7865
#    macro avg       0.92      0.77      0.82      7865
# weighted avg       0.95      0.96      0.95      7865
#
# storm
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      7127
#            1       0.77      0.46      0.58       738
#
#     accuracy                           0.94      7865
#    macro avg       0.86      0.73      0.77      7865
# weighted avg       0.93      0.94      0.93      7865
#
# fire
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7782
#            1       0.50      0.12      0.19        83
#
#     accuracy                           0.99      7865
#    macro avg       0.75      0.56      0.59      7865
# weighted avg       0.99      0.99      0.99      7865
#
# earthquake
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      7163
#            1       0.88      0.79      0.83       702
#
#     accuracy                           0.97      7865
#    macro avg       0.93      0.89      0.91      7865
# weighted avg       0.97      0.97      0.97      7865
#
# cold
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7694
#            1       0.73      0.32      0.45       171
#
#     accuracy                           0.98      7865
#    macro avg       0.86      0.66      0.72      7865
# weighted avg       0.98      0.98      0.98      7865
#
# other_weather
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      7450
#            1       0.56      0.11      0.18       415
#
#     accuracy                           0.95      7865
#    macro avg       0.75      0.55      0.58      7865
# weighted avg       0.93      0.95      0.93      7865
#
# direct_report
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.91      6321
#            1       0.78      0.34      0.47      1544
#
#     accuracy                           0.85      7865
#    macro avg       0.82      0.66      0.69      7865
# weighted avg       0.84      0.85      0.83      7865
#
# ____________________________________________________________________________________

# %%
for i in range(len(cv_list)):
    print(cv_list[i].best_estimator_)
# Out:
# Pipeline(steps=[('vect',
#                  CountVectorizer(tokenizer=<function tokenize at 0x000002592B0C2040>)),
#                 ('tfidf', TfidfTransformer()),
#                 ('clf',
#                  MultiOutputClassifier(estimator=RandomForestClassifier(n_estimators=200,
#                                                                         n_jobs=-1)))])
# Pipeline(steps=[('vect',
#                  CountVectorizer(tokenizer=<function tokenize at 0x000002592B0C2040>)),
#                 ('tfidf', TfidfTransformer(use_idf=False)),
#                 ('clf',
#                  MultiOutputClassifier(estimator=GradientBoostingClassifier(learning_rate=0.05,
#                                                                             n_estimators=200)))])
# Pipeline(steps=[('vect',
#                  CountVectorizer(tokenizer=<function tokenize at 0x000002592B0C2040>)),
#                 ('tfidf', TfidfTransformer()),
#                 ('clf',
#                  MultiOutputClassifier(estimator=AdaBoostClassifier(learning_rate=0.2,
#                                                                     n_estimators=300)))])

# %% [markdown]
# ### 7. Test your model
# Show the accuracy, precision, and recall of the tuned model.
#
# Since this project focuses on code quality, process, and  pipelines, there is no minimum performance metric needed to pass. However, make sure to fine tune your models for accuracy, precision and recall to make your project stand out - especially for your portfolio!

# %%
rf_clf = cv_list[0].best_estimator_
gb_clf = cv_list[1].best_estimator_
ab_clf = cv_list[2].best_estimator_

best_estimators = [rf_clf, gb_clf, ab_clf]

# %%
for best_estimator in best_estimators:
    print(best_estimator)
    y_pred = pd.DataFrame(best_estimator.predict(X_test_array), columns=y_train.columns.tolist())
    print()
    print(classification_report(y_test.melt().value, y_pred.melt().value, zero_division=0))
    print('_______________________________________________________________________________________')
    print()
# Out:
# Pipeline(steps=[('vect',
#                  CountVectorizer(tokenizer=<function tokenize at 0x000002592B0C2040>)),
#                 ('tfidf', TfidfTransformer()),
#                 ('clf',
#                  MultiOutputClassifier(estimator=RandomForestClassifier(n_estimators=200,
#                                                                         n_jobs=-1)))])
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97    250476
#            1       0.81      0.52      0.64     24741
#            2       0.50      0.48      0.49        58
#
#     accuracy                           0.95    275275
#    macro avg       0.76      0.67      0.70    275275
# weighted avg       0.94      0.95      0.94    275275
#
# _______________________________________________________________________________________
#
# Pipeline(steps=[('vect',
#                  CountVectorizer(tokenizer=<function tokenize at 0x000002592B0C2040>)),
#                 ('tfidf', TfidfTransformer(use_idf=False)),
#                 ('clf',
#                  MultiOutputClassifier(estimator=GradientBoostingClassifier(learning_rate=0.05,
#                                                                             n_estimators=200)))])
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97    250476
#            1       0.78      0.56      0.65     24741
#            2       0.74      0.24      0.36        58
#
#     accuracy                           0.95    275275
#    macro avg       0.83      0.60      0.66    275275
# weighted avg       0.94      0.95      0.94    275275
#
# _______________________________________________________________________________________
#
# Pipeline(steps=[('vect',
#                  CountVectorizer(tokenizer=<function tokenize at 0x000002592B0C2040>)),
#                 ('tfidf', TfidfTransformer()),
#                 ('clf',
#                  MultiOutputClassifier(estimator=AdaBoostClassifier(learning_rate=0.2,
#                                                                     n_estimators=300)))])
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97    250476
#            1       0.78      0.56      0.65     24741
#            2       0.57      0.07      0.12        58
#
#     accuracy                           0.95    275275
#    macro avg       0.77      0.54      0.58    275275
# weighted avg       0.94      0.95      0.94    275275
#
# _______________________________________________________________________________________

# %% [markdown]
# ## Model evaluation
#
# The classification report shows a slight better scoring (especialls the precision, recall and f1-score) for value = 1 for the Gradient Boosting Classifier.
# This model will be chosen as final model to implement

# %% [markdown]
# ### 8. Try improving your model further. Here are a few ideas:
# * try other machine learning algorithms
# * add other features besides the TF-IDF

# %% [markdown]
# ### 9. Export your model as a pickle file

# %%
dump(gb_clf, r'.\gb_classifier.joblib')
# Out:
# ['.\\gb_classifier.joblib']

# %% [markdown]
# ### 10. Use this notebook to complete `train.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database and export a model based on a new dataset specified by the user.
